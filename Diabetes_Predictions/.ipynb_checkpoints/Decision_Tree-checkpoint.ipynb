# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.compost import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler,StandardScaler,OneHotEncoder,OrdinalEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       6 from sklearn.tree import DecisionTreeRegressor
#       7 from sklearn.model_selection import train_test_split
# ----> 8 from sklearn.compost import ColumnTransformer
#       9 from sklearn.pipeline import Pipeline
#      10 from sklearn.preprocessing import MinMaxScaler,StandardScaler,OneHotEncoder,OrdinalEncoder
#
# ModuleNotFoundError: No module named 'sklearn.compost'
